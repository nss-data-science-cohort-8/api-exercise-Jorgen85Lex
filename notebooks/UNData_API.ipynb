# %% [markdown]
# ## UNData API Exercise
#
# In this exercise, you'll redo the data gathering phase of the UNData Exploration project by using APIs instead of downloading csv files.
#
# You'll make use of the [World Bank Indicators API](https://datahelpdesk.worldbank.org/knowledgebase/articles/889392-about-the-indicators-api-documentation). Note that this API does not require an API key. Before attempting the exercise, it would be a good idea to skim through the Documentation page and to check out the [Basic Call Structure article](https://datahelpdesk.worldbank.org/knowledgebase/articles/898581).
#
# 1. Use the API to get all available data for the _GDP per capita, PPP (constant 2021 international $)_ indicator. Hint: this indicator has code "NY.GDP.PCAP.PP.KD". Adjust the query parameters so that you can retrieve all available rows. Convert the results to a DataFrame.
#
# 2. Now, use the API to get all available data for _Life expectancy at birth, total (years)_. This indicator has code "SP.DYN.LE00.IN". Again, convert the results to a DataFrame.
#
# 3. Merge the two results DataFrames together. You may want to rename or drop columns prior to merging.
#
# 4. You can also get more information about the available countries (region, capital city, income level classification, etc.) by using the [Country API](https://datahelpdesk.worldbank.org/knowledgebase/articles/898590-country-api-queries). Use this API to pull in all available data. Merge this with your other datasets. Use this to now remove the rows that correspond to regions and not countries.

# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np

# %%
endpoint_GDP = 'https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.PP.KD?format=json'

params_GDP = {
'per_page': 20000
}

response_GDP = requests.get(endpoint_GDP,params = params_GDP)
response_GDP
# Out:
# <Response [200]>

# %%
GDP_df = pd.json_normalize(response_GDP.json()[1])
GDP_df
# Out:
#       countryiso3code  date        value unit obs_status  decimal  \
# 0                 AFE  2023  4047.007031                        0
# 1                 AFE  2022  4038.638689                        0
# 2                 AFE  2021  3994.171654                        0
# 3                 AFE  2020  3919.499230                        0
# 4                 AFE  2019  4130.057222                        0
# ...               ...   ...          ...  ...        ...      ...
# 17019             ZWE  1964          NaN                        0
# 17020             ZWE  1963          NaN                        0
# 17021             ZWE  1962          NaN                        0
# 17022             ZWE  1961          NaN                        0
# 17023             ZWE  1960          NaN                        0
#
#             indicator.id                                    indicator.value  \
# 0      NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 1      NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 2      NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 3      NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 4      NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# ...                  ...                                                ...
# 17019  NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 17020  NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 17021  NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 17022  NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 17023  NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
#
#       country.id                country.value
# 0             ZH  Africa Eastern and Southern
# 1             ZH  Africa Eastern and Southern
# 2             ZH  Africa Eastern and Southern
# 3             ZH  Africa Eastern and Southern
# 4             ZH  Africa Eastern and Southern
# ...          ...                          ...
# 17019         ZW                     Zimbabwe
# 17020         ZW                     Zimbabwe
# 17021         ZW                     Zimbabwe
# 17022         ZW                     Zimbabwe
# 17023         ZW                     Zimbabwe
#
# [17024 rows x 10 columns]

# %%
endpoint_LE = 'https://api.worldbank.org/v2/country/all/indicator/SP.DYN.LE00.IN?format=json'

params_LE = {
'per_page': 20000
}

response_LE = requests.get(endpoint_LE, params=params_LE)
response_LE
# Out:
# <Response [200]>

# %%
life_expectancy_df = pd.json_normalize(response_LE.json()[1])
life_expectancy_df
# Out:
#       countryiso3code  date      value unit obs_status  decimal  \
# 0                 AFE  2023        NaN                        0
# 1                 AFE  2022  62.899031                        0
# 2                 AFE  2021  62.454590                        0
# 3                 AFE  2020  63.313860                        0
# 4                 AFE  2019  63.755678                        0
# ...               ...   ...        ...  ...        ...      ...
# 17019             ZWE  1964  54.994000                        0
# 17020             ZWE  1963  54.549000                        0
# 17021             ZWE  1962  54.071000                        0
# 17022             ZWE  1961  53.619000                        0
# 17023             ZWE  1960  53.235000                        0
#
#          indicator.id                          indicator.value country.id  \
# 0      SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZH
# 1      SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZH
# 2      SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZH
# 3      SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZH
# 4      SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZH
# ...               ...                                      ...        ...
# 17019  SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZW
# 17020  SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZW
# 17021  SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZW
# 17022  SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZW
# 17023  SP.DYN.LE00.IN  Life expectancy at birth, total (years)         ZW
#
#                      country.value
# 0      Africa Eastern and Southern
# 1      Africa Eastern and Southern
# 2      Africa Eastern and Southern
# 3      Africa Eastern and Southern
# 4      Africa Eastern and Southern
# ...                            ...
# 17019                     Zimbabwe
# 17020                     Zimbabwe
# 17021                     Zimbabwe
# 17022                     Zimbabwe
# 17023                     Zimbabwe
#
# [17024 rows x 10 columns]

# %%
GDP_df = GDP_df.rename(columns=
              {'countryiso3code' : 'Country_Code',  
               'country.id' : 'Country_ID', 
               'country.value' : 'Country_Value',
               'date' : 'Date',
               'value' : 'GDP_Per_Capita'})

# %%
GDP_df = GDP_df.drop(['unit', 'obs_status', 'decimal','indicator.id', 'indicator.value'], axis=1)
GDP_df
# Out:
#       Country_Code  Date  GDP_Per_Capita Country_ID  \
# 0              AFE  2023     4047.007031         ZH
# 1              AFE  2022     4038.638689         ZH
# 2              AFE  2021     3994.171654         ZH
# 3              AFE  2020     3919.499230         ZH
# 4              AFE  2019     4130.057222         ZH
# ...            ...   ...             ...        ...
# 17019          ZWE  1964             NaN         ZW
# 17020          ZWE  1963             NaN         ZW
# 17021          ZWE  1962             NaN         ZW
# 17022          ZWE  1961             NaN         ZW
# 17023          ZWE  1960             NaN         ZW
#
#                      Country_Value
# 0      Africa Eastern and Southern
# 1      Africa Eastern and Southern
# 2      Africa Eastern and Southern
# 3      Africa Eastern and Southern
# 4      Africa Eastern and Southern
# ...                            ...
# 17019                     Zimbabwe
# 17020                     Zimbabwe
# 17021                     Zimbabwe
# 17022                     Zimbabwe
# 17023                     Zimbabwe
#
# [17024 rows x 5 columns]

# %%
life_expectancy_df = life_expectancy_df.rename(columns=
              {'countryiso3code' : 'Country_Code',
               'country.id' : 'Country_ID', 
               'country.value' : 'Country_Value',
               'date' : 'Date',
               'value' : 'Life_Expectancy'})

# %%
life_expectancy_df = life_expectancy_df.drop(['unit', 'obs_status', 'decimal', 'indicator.id', 'indicator.value'], axis=1)
life_expectancy_df
# Out:
#       Country_Code  Date  Life_Expectancy Country_ID  \
# 0              AFE  2023              NaN         ZH
# 1              AFE  2022        62.899031         ZH
# 2              AFE  2021        62.454590         ZH
# 3              AFE  2020        63.313860         ZH
# 4              AFE  2019        63.755678         ZH
# ...            ...   ...              ...        ...
# 17019          ZWE  1964        54.994000         ZW
# 17020          ZWE  1963        54.549000         ZW
# 17021          ZWE  1962        54.071000         ZW
# 17022          ZWE  1961        53.619000         ZW
# 17023          ZWE  1960        53.235000         ZW
#
#                      Country_Value
# 0      Africa Eastern and Southern
# 1      Africa Eastern and Southern
# 2      Africa Eastern and Southern
# 3      Africa Eastern and Southern
# 4      Africa Eastern and Southern
# ...                            ...
# 17019                     Zimbabwe
# 17020                     Zimbabwe
# 17021                     Zimbabwe
# 17022                     Zimbabwe
# 17023                     Zimbabwe
#
# [17024 rows x 5 columns]

# %%
merged_GDP_le = pd.merge(GDP_df, life_expectancy_df, how="inner", on = ["Country_Code", "Date", "Country_ID", "Country_Value"])
merged_GDP_le.head()
# Out:
#   Country_Code  Date  GDP_Per_Capita Country_ID                Country_Value  \
# 0          AFE  2023     4047.007031         ZH  Africa Eastern and Southern
# 1          AFE  2022     4038.638689         ZH  Africa Eastern and Southern
# 2          AFE  2021     3994.171654         ZH  Africa Eastern and Southern
# 3          AFE  2020     3919.499230         ZH  Africa Eastern and Southern
# 4          AFE  2019     4130.057222         ZH  Africa Eastern and Southern
#
#    Life_Expectancy
# 0              NaN
# 1        62.899031
# 2        62.454590
# 3        63.313860
# 4        63.755678

# %%
endpoint_country = 'https://api.worldbank.org/v2/country/all?format=json'

params_country = {
'per_page': 300
}

response_country = requests.get(endpoint_country, params = params_country)
response_country
# Out:
# <Response [200]>

# %%
country_df = pd.json_normalize(response_country.json()[1])
country_df.head()
# Out:
#     id iso2Code                         name capitalCity longitude latitude  \
# 0  ABW       AW                        Aruba  Oranjestad  -70.0167  12.5167
# 1  AFE       ZH  Africa Eastern and Southern
# 2  AFG       AF                  Afghanistan       Kabul   69.1761  34.5228
# 3  AFR       A9                       Africa
# 4  AFW       ZI   Africa Western and Central
#
#   region.id region.iso2code                region.value adminregion.id  \
# 0       LCN              ZJ  Latin America & Caribbean
# 1        NA              NA                  Aggregates
# 2       SAS              8S                  South Asia            SAS
# 3        NA              NA                  Aggregates
# 4        NA              NA                  Aggregates
#
#   adminregion.iso2code adminregion.value incomeLevel.id incomeLevel.iso2code  \
# 0                                                   HIC                   XD
# 1                                                    NA                   NA
# 2                   8S        South Asia            LIC                   XM
# 3                                                    NA                   NA
# 4                                                    NA                   NA
#
#   incomeLevel.value lendingType.id lendingType.iso2code lendingType.value
# 0       High income            LNX                   XX    Not classified
# 1        Aggregates                                            Aggregates
# 2        Low income            IDX                   XI               IDA
# 3        Aggregates                                            Aggregates
# 4        Aggregates                                            Aggregates

# %%
country_df = country_df.rename(columns=
              {'name': 'Country_Value',
               'id': 'Country_Code',
              'iso2Code': 'Country_ID'}
)
country_df
# Out:
#     Country_Code Country_ID  \
# 0            ABW         AW
# 1            AFE         ZH
# 2            AFG         AF
# 3            AFR         A9
# 4            AFW         ZI
# ..           ...        ...
# 291          XZN         A5
# 292          YEM         YE
# 293          ZAF         ZA
# 294          ZMB         ZM
# 295          ZWE         ZW
#
#                                          Country_Value capitalCity longitude  \
# 0                                                Aruba  Oranjestad  -70.0167
# 1                          Africa Eastern and Southern
# 2                                          Afghanistan       Kabul   69.1761
# 3                                               Africa
# 4                           Africa Western and Central
# ..                                                 ...         ...       ...
# 291  Sub-Saharan Africa excluding South Africa and ...
# 292                                        Yemen, Rep.      Sana'a   44.2075
# 293                                       South Africa    Pretoria   28.1871
# 294                                             Zambia      Lusaka   28.2937
# 295                                           Zimbabwe      Harare   31.0672
#
#      latitude region.id region.iso2code                region.value  \
# 0     12.5167       LCN              ZJ  Latin America & Caribbean
# 1                    NA              NA                  Aggregates
# 2     34.5228       SAS              8S                  South Asia
# 3                    NA              NA                  Aggregates
# 4                    NA              NA                  Aggregates
# ..        ...       ...             ...                         ...
# 291                  NA              NA                  Aggregates
# 292    15.352       MEA              ZQ  Middle East & North Africa
# 293   -25.746       SSF              ZG         Sub-Saharan Africa
# 294  -15.3982       SSF              ZG         Sub-Saharan Africa
# 295  -17.8312       SSF              ZG         Sub-Saharan Africa
#
#     adminregion.id adminregion.iso2code  \
# 0
# 1
# 2              SAS                   8S
# 3
# 4
# ..             ...                  ...
# 291
# 292            MNA                   XQ
# 293            SSA                   ZF
# 294            SSA                   ZF
# 295            SSA                   ZF
#
#                                      adminregion.value incomeLevel.id  \
# 0                                                                 HIC
# 1                                                                  NA
# 2                                           South Asia            LIC
# 3                                                                  NA
# 4                                                                  NA
# ..                                                 ...            ...
# 291                                                                NA
# 292  Middle East & North Africa (excluding high inc...            LIC
# 293         Sub-Saharan Africa (excluding high income)            UMC
# 294         Sub-Saharan Africa (excluding high income)            LMC
# 295         Sub-Saharan Africa (excluding high income)            LMC
#
#     incomeLevel.iso2code    incomeLevel.value lendingType.id  \
# 0                     XD          High income            LNX
# 1                     NA           Aggregates
# 2                     XM           Low income            IDX
# 3                     NA           Aggregates
# 4                     NA           Aggregates
# ..                   ...                  ...            ...
# 291                   NA           Aggregates
# 292                   XM           Low income            IDX
# 293                   XT  Upper middle income            IBD
# 294                   XN  Lower middle income            IDX
# 295                   XN  Lower middle income            IDB
#
#     lendingType.iso2code lendingType.value
# 0                     XX    Not classified
# 1                               Aggregates
# 2                     XI               IDA
# 3                               Aggregates
# 4                               Aggregates
# ..                   ...               ...
# 291                             Aggregates
# 292                   XI               IDA
# 293                   XF              IBRD
# 294                   XI               IDA
# 295                   XH             Blend
#
# [296 rows x 18 columns]

# %%
merged_GDP_le_country = pd.merge(merged_GDP_le, country_df, how="inner", on= ["Country_Code", "Country_ID", "Country_Value"])
merged_GDP_le_country
# Out:
#       Country_Code  Date  GDP_Per_Capita Country_ID  \
# 0              AFE  2023     4047.007031         ZH
# 1              AFE  2022     4038.638689         ZH
# 2              AFE  2021     3994.171654         ZH
# 3              AFE  2020     3919.499230         ZH
# 4              AFE  2019     4130.057222         ZH
# ...            ...   ...             ...        ...
# 16571          ZWE  1964             NaN         ZW
# 16572          ZWE  1963             NaN         ZW
# 16573          ZWE  1962             NaN         ZW
# 16574          ZWE  1961             NaN         ZW
# 16575          ZWE  1960             NaN         ZW
#
#                      Country_Value  Life_Expectancy capitalCity longitude  \
# 0      Africa Eastern and Southern              NaN
# 1      Africa Eastern and Southern        62.899031
# 2      Africa Eastern and Southern        62.454590
# 3      Africa Eastern and Southern        63.313860
# 4      Africa Eastern and Southern        63.755678
# ...                            ...              ...         ...       ...
# 16571                     Zimbabwe        54.994000      Harare   31.0672
# 16572                     Zimbabwe        54.549000      Harare   31.0672
# 16573                     Zimbabwe        54.071000      Harare   31.0672
# 16574                     Zimbabwe        53.619000      Harare   31.0672
# 16575                     Zimbabwe        53.235000      Harare   31.0672
#
#        latitude region.id  ...         region.value adminregion.id  \
# 0                      NA  ...           Aggregates
# 1                      NA  ...           Aggregates
# 2                      NA  ...           Aggregates
# 3                      NA  ...           Aggregates
# 4                      NA  ...           Aggregates
# ...         ...       ...  ...                  ...            ...
# 16571  -17.8312       SSF  ...  Sub-Saharan Africa             SSA
# 16572  -17.8312       SSF  ...  Sub-Saharan Africa             SSA
# 16573  -17.8312       SSF  ...  Sub-Saharan Africa             SSA
# 16574  -17.8312       SSF  ...  Sub-Saharan Africa             SSA
# 16575  -17.8312       SSF  ...  Sub-Saharan Africa             SSA
#
#       adminregion.iso2code                           adminregion.value  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...                                         ...
# 16571                   ZF  Sub-Saharan Africa (excluding high income)
# 16572                   ZF  Sub-Saharan Africa (excluding high income)
# 16573                   ZF  Sub-Saharan Africa (excluding high income)
# 16574                   ZF  Sub-Saharan Africa (excluding high income)
# 16575                   ZF  Sub-Saharan Africa (excluding high income)
#
#       incomeLevel.id incomeLevel.iso2code    incomeLevel.value lendingType.id  \
# 0                 NA                   NA           Aggregates
# 1                 NA                   NA           Aggregates
# 2                 NA                   NA           Aggregates
# 3                 NA                   NA           Aggregates
# 4                 NA                   NA           Aggregates
# ...              ...                  ...                  ...            ...
# 16571            LMC                   XN  Lower middle income            IDB
# 16572            LMC                   XN  Lower middle income            IDB
# 16573            LMC                   XN  Lower middle income            IDB
# 16574            LMC                   XN  Lower middle income            IDB
# 16575            LMC                   XN  Lower middle income            IDB
#
#       lendingType.iso2code lendingType.value
# 0                                 Aggregates
# 1                                 Aggregates
# 2                                 Aggregates
# 3                                 Aggregates
# 4                                 Aggregates
# ...                    ...               ...
# 16571                   XH             Blend
# 16572                   XH             Blend
# 16573                   XH             Blend
# 16574                   XH             Blend
# 16575                   XH             Blend
#
# [16576 rows x 21 columns]

# %%
merged_GDP_le_country = merged_GDP_le_country[merged_GDP_le_country['region.id'] != 'NA']
merged_GDP_le_country
# Out:
#       Country_Code  Date  GDP_Per_Capita Country_ID Country_Value  \
# 2688           AFG  2023             NaN         AF   Afghanistan
# 2689           AFG  2022     1955.212904         AF   Afghanistan
# 2690           AFG  2021     2138.870247         AF   Afghanistan
# 2691           AFG  2020     2776.561521         AF   Afghanistan
# 2692           AFG  2019     2933.958598         AF   Afghanistan
# ...            ...   ...             ...        ...           ...
# 16571          ZWE  1964             NaN         ZW      Zimbabwe
# 16572          ZWE  1963             NaN         ZW      Zimbabwe
# 16573          ZWE  1962             NaN         ZW      Zimbabwe
# 16574          ZWE  1961             NaN         ZW      Zimbabwe
# 16575          ZWE  1960             NaN         ZW      Zimbabwe
#
#        Life_Expectancy capitalCity longitude  latitude region.id  ...  \
# 2688               NaN       Kabul   69.1761   34.5228       SAS  ...
# 2689            62.879       Kabul   69.1761   34.5228       SAS  ...
# 2690            61.982       Kabul   69.1761   34.5228       SAS  ...
# 2691            62.575       Kabul   69.1761   34.5228       SAS  ...
# 2692            63.565       Kabul   69.1761   34.5228       SAS  ...
# ...                ...         ...       ...       ...       ...  ...
# 16571           54.994      Harare   31.0672  -17.8312       SSF  ...
# 16572           54.549      Harare   31.0672  -17.8312       SSF  ...
# 16573           54.071      Harare   31.0672  -17.8312       SSF  ...
# 16574           53.619      Harare   31.0672  -17.8312       SSF  ...
# 16575           53.235      Harare   31.0672  -17.8312       SSF  ...
#
#               region.value adminregion.id adminregion.iso2code  \
# 2688            South Asia            SAS                   8S
# 2689            South Asia            SAS                   8S
# 2690            South Asia            SAS                   8S
# 2691            South Asia            SAS                   8S
# 2692            South Asia            SAS                   8S
# ...                    ...            ...                  ...
# 16571  Sub-Saharan Africa             SSA                   ZF
# 16572  Sub-Saharan Africa             SSA                   ZF
# 16573  Sub-Saharan Africa             SSA                   ZF
# 16574  Sub-Saharan Africa             SSA                   ZF
# 16575  Sub-Saharan Africa             SSA                   ZF
#
#                                 adminregion.value incomeLevel.id  \
# 2688                                   South Asia            LIC
# 2689                                   South Asia            LIC
# 2690                                   South Asia            LIC
# 2691                                   South Asia            LIC
# 2692                                   South Asia            LIC
# ...                                           ...            ...
# 16571  Sub-Saharan Africa (excluding high income)            LMC
# 16572  Sub-Saharan Africa (excluding high income)            LMC
# 16573  Sub-Saharan Africa (excluding high income)            LMC
# 16574  Sub-Saharan Africa (excluding high income)            LMC
# 16575  Sub-Saharan Africa (excluding high income)            LMC
#
#       incomeLevel.iso2code    incomeLevel.value lendingType.id  \
# 2688                    XM           Low income            IDX
# 2689                    XM           Low income            IDX
# 2690                    XM           Low income            IDX
# 2691                    XM           Low income            IDX
# 2692                    XM           Low income            IDX
# ...                    ...                  ...            ...
# 16571                   XN  Lower middle income            IDB
# 16572                   XN  Lower middle income            IDB
# 16573                   XN  Lower middle income            IDB
# 16574                   XN  Lower middle income            IDB
# 16575                   XN  Lower middle income            IDB
#
#       lendingType.iso2code lendingType.value
# 2688                    XI               IDA
# 2689                    XI               IDA
# 2690                    XI               IDA
# 2691                    XI               IDA
# 2692                    XI               IDA
# ...                    ...               ...
# 16571                   XH             Blend
# 16572                   XH             Blend
# 16573                   XH             Blend
# 16574                   XH             Blend
# 16575                   XH             Blend
#
# [13888 rows x 21 columns]

# %% [markdown]
# You can also get more information about the available countries (region, capital city, income level classification, etc.) by using the Country API. Use this API to pull in all available data. Merge this with your other datasets. Use this to now remove the rows that correspond to regions and not countries.
